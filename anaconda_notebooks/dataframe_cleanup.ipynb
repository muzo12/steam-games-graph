# %%
import pandas as pd
import numpy as np
df = pd.read_csv("C:\\Users\\Admin\\Documents\\GitHub\\GamesGraph\\scripts\\wip_data\\_dataframe_merged.csv",index_col=0,dtype=np.float16)
df.head()
# Out:
#      appid10  appid100  appid10000  appid1002  appid10040  appid100400  \
# inf      1.0       1.0         NaN        NaN         NaN          NaN
# inf      1.0       1.0         NaN        NaN         NaN          NaN
# inf      NaN       NaN         NaN        NaN         NaN          NaN
# inf      1.0       1.0         NaN        NaN         NaN          NaN
# inf      1.0       1.0         NaN        NaN         NaN          NaN
#
#      appid100410  appid10080  appid10090  appid100970  ...   appid9980  \
# inf          NaN         NaN         NaN          NaN  ...         NaN
# inf          NaN         NaN         NaN          NaN  ...         NaN
# inf          NaN         NaN         NaN          NaN  ...         NaN
# inf          NaN         NaN         NaN          NaN  ...         NaN
# inf          NaN         NaN         NaN          NaN  ...         NaN
#
#      appid99810  appid99830  appid99890  appid9990  appid99900  appid99910  \
# ...

# %%
df.drop('profile', inplace=True)
df.drop('time',inplace=True)

# %%
game_users_treshold = 100
for index, col in df.iteritems():
    if col.count() < game_users_treshold:
        print(index,col.count(),'dropped!')
        df.drop(index, inplace=True)
# Out:
# appid10000 75 dropped!
# appid10040 2 dropped!
# appid100400 43 dropped!
# appid10080 53 dropped!
# appid100970 47 dropped!
# appid100980 41 dropped!
# appid10120 42 dropped!
# appid10140 54 dropped!
# appid10230 73 dropped!
# appid10240 91 dropped!
# appid10250 75 dropped!
# appid10260 73 dropped!
# appid10400 31 dropped!
# appid10410 2 dropped!
# appid10420 3 dropped!
# appid10470 5 dropped!
# appid10480 4 dropped!
# appid10490 1 dropped!
# appid105200 10 dropped!
# appid10560 12 dropped!
# appid10590 5 dropped!
# appid10630 10 dropped!
# appid10650 76 dropped!
# appid10660 30 dropped!
# appid10690 64 dropped!
# appid107000 17 dropped!
# appid109700 82 dropped!
# appid11060 26 dropped!
# appid111000 78 dropped!
# appid111010 64 dropped!
# appid11120 18 dropped!
# appid111300 44 dropped!
# appid11520 17 dropped!
# appid11550 61 dropped!
# appid12300 16 dropped!
# appid12400 11 dropped!
# appid12550 10 dropped!
# appid12630 31 dropped!
# appid12650 45 dropped!
# ...

# %%
df.to_csv("C:\\Users\\Admin\\Documents\\GitHub\\GamesGraph\\scripts\\wip_data\\_dataframe_merged_cleaned.csv")
