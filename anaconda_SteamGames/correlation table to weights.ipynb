# %%
import pandas as pd
import math
df = pd.read_csv("pearsons_corr.csv", encoding='utf-8', index_col=0)

# %%
df.head()
# Out:
#                                                神明的一天世界(God's One Day World)  \
#  神明的一天世界(God's One Day World)                                      1.000000
# ! That Bastard Is Trying To Steal Our Gold !                       0.446981
# "Glow Ball" - The billiard puzzle game                             0.255948
# #SelfieTennis                                                     -0.001260
# #SkiJump                                                          -0.001202
#
#                                               ! That Bastard Is Trying To Steal Our Gold !  \
#  神明的一天世界(God's One Day World)                                                     0.446981
# ! That Bastard Is Trying To Steal Our Gold !                                      1.000000
# "Glow Ball" - The billiard puzzle game                                            0.318198
# #SelfieTennis                                                                    -0.001043
# #SkiJump                                                                         -0.000994
#
#                                               "Glow Ball" - The billiard puzzle game  \
#  神明的一天世界(God's One Day World)                                               0.255948
# ! That Bastard Is Trying To Steal Our Gold !                                0.318198
# "Glow Ball" - The billiard puzzle game                                      1.000000
# #SelfieTennis                                                              -0.002209
# #SkiJump                                                                   -0.002107
#
#                                               #SelfieTennis  #SkiJump  \
#  神明的一天世界(God's One Day World)                     -0.001260 -0.001202
# ! That Bastard Is Trying To Steal Our Gold !      -0.001043 -0.000994
# "Glow Ball" - The billiard puzzle game            -0.002209 -0.002107
# #SelfieTennis                                      1.000000  0.285861
# #SkiJump                                           0.285861  1.000000
#
#                                               #killallzombies   $1 Ride  \
#  神明的一天世界(God's One Day World)                        0.120596  0.286055
# ! That Bastard Is Trying To Steal Our Gold !         0.166967  0.287437
# "Glow Ball" - The billiard puzzle game               0.057979  0.249759
# #SelfieTennis                                       -0.000284 -0.002649
# #SkiJump                                            -0.000271 -0.002526
#
#                                               'n Verlore Verstand  \
#  神明的一天世界(God's One Day World)                            0.511553
# ! That Bastard Is Trying To Steal Our Gold !             0.514008
# "Glow Ball" - The billiard puzzle game                   0.258954
# #SelfieTennis                                            0.022147
# #SkiJump                                                -0.000980
#
#                                               - Arcane Raise -  \
#  神明的一天世界(God's One Day World)                         0.168028
# ! That Bastard Is Trying To Steal Our Gold !          0.189452
# "Glow Ball" - The billiard puzzle game                0.237199
# #SelfieTennis                                        -0.001173
# #SkiJump                                             -0.001118
#
#                                               -- none -- [Not currently available]  \
#  神明的一天世界(God's One Day World)                                             0.362105
# ! That Bastard Is Trying To Steal Our Gold !                              0.414878
# "Glow Ball" - The billiard puzzle game                                    0.212174
# #SelfieTennis                                                            -0.000772
# #SkiJump                                                                 -0.000736
#
#                                                                                  ...                                       \
#  神明的一天世界(God's One Day World)                                                    ...
# ! That Bastard Is Trying To Steal Our Gold !                                     ...
# "Glow Ball" - The billiard puzzle game                                           ...
# #SelfieTennis                                                                    ...
# #SkiJump                                                                         ...
#
#                                               ファイナルファンタジーXIV: 新生エオルゼア (JP version)  \
#  神明的一天世界(God's One Day World)                                            -0.001520
# ! That Bastard Is Trying To Steal Our Gold !                             -0.001258
# "Glow Ball" - The billiard puzzle game                                   -0.002665
# #SelfieTennis                                                            -0.000315
# #SkiJump                                                                  0.078781
#
#                                               丛林守望者（Ranger of the jungle）  \
#  神明的一天世界(God's One Day World)                                    0.648984
# ! That Bastard Is Trying To Steal Our Gold !                     0.499728
# "Glow Ball" - The billiard puzzle game                           0.263664
# #SelfieTennis                                                   -0.001093
# #SkiJump                                                        -0.001042
#
#                                               乖離性ミリオンアーサー VR  \
#  神明的一天世界(God's One Day World)                      -0.001202
# ! That Bastard Is Trying To Steal Our Gold !       -0.000994
# "Glow Ball" - The billiard puzzle game             -0.002107
# #SelfieTennis                                       0.285861
# #SkiJump                                            1.000000
#
#                                               侠客风云传(Tale of Wuxia)  \
#  神明的一天世界(God's One Day World)                             0.066986
# ! That Bastard Is Trying To Steal Our Gold !              0.039776
# "Glow Ball" - The billiard puzzle game                    0.010296
# #SelfieTennis                                            -0.000568
# #SkiJump                                                 -0.000541
#
#                                               大海战 Navy Field IV  \
#  神明的一天世界(God's One Day World)                          0.149641
# ! That Bastard Is Trying To Steal Our Gold !           0.145112
# "Glow Ball" - The billiard puzzle game                 0.187531
# #SelfieTennis                                         -0.001121
# #SkiJump                                              -0.001069
#
#                                               天使帝國四《Empire of Angels IV》  \
#  神明的一天世界(God's One Day World)                                   0.102985
# ! That Bastard Is Trying To Steal Our Gold !                    0.030090
# "Glow Ball" - The billiard puzzle game                          0.019505
# #SelfieTennis                                                  -0.000377
# #SkiJump                                                       -0.000360
#
#                                               画境(Picturesque) VR  \
#  神明的一天世界(God's One Day World)                           0.484835
# ! That Bastard Is Trying To Steal Our Gold !            0.473657
# "Glow Ball" - The billiard puzzle game                  0.220938
# #SelfieTennis                                          -0.000902
# #SkiJump                                               -0.000860
#
#                                               神楽道中記(KaguraDouchuuki)  \
#  神明的一天世界(God's One Day World)                               0.198169
# ! That Bastard Is Trying To Steal Our Gold !                0.108262
# "Glow Ball" - The billiard puzzle game                      0.050064
# #SelfieTennis                                              -0.000273
# #SkiJump                                                   -0.000260
#
#                                               軒轅劍外傳穹之扉(The Gate of Firmament)  \
#  神明的一天世界(God's One Day World)                                        0.082066
# ! That Bastard Is Trying To Steal Our Gold !                         0.031560
# "Glow Ball" - The billiard puzzle game                               0.010558
# #SelfieTennis                                                        0.033480
# #SkiJump                                                             0.035180
#
#                                               軒轅劍外傳穹之扉音樂精選集(Sound Collection of Xuan-Yuan Sword EX：The Gate of Firmament)
#  神明的一天世界(God's One Day World)                                                          0.012757
# ! That Bastard Is Trying To Steal Our Gold !                                           0.016011
# "Glow Ball" - The billiard puzzle game                                                 0.005421
# #SelfieTennis                                                                          0.068853
# #SkiJump                                                                               0.072246
#
# [5 rows x 12950 columns]

# %%
games_nodes_size = {}
with open("nodes_weights.csv", encoding='utf-8') as f:
    for line in f.readlines():
        game, _, weight = line.split("\t")
        games_nodes_size[game] = weight
print(len(games_nodes_size))
# Out:
# 12951

# %%
#output_df=pd.DataFrame()
file = open("pearsons_cleaned_for_gephi_squared.csv", 'w', encoding='utf')
file.write("Source\tTarget\tWeight\n")
game_number=0
for source, row in df.iterrows():
    mean = row.mean()
    std = row.std()
    treshold=mean+2*std
    
    #print(i,"/12950", source, "mean:",str(mean),"std",str(std),"treshold:",str(treshold))
    if (game_number%1000 == 0): print(game_number)
    #print(i,"/12950")
    #game_df=pd.DataFrame()
    
    edges_t = {}
    edges_w = {}
    
    for target, weight in row.iteritems():
        if ((source==target)|(weight<treshold)):
            continue
        edges_t[target] = target
        edges_w[target] = weight ** 2
    
    sorted_targets = sorted(edges_t, key=edges_w.__getitem__, reverse=True)
    
    iter_range = min(len(edges_t),1*float(games_nodes_size[source]))
    for i in range(int(iter_range)):
        #print(source+"\t"+edges_t[sorted_targets[i]]+"\t"+str(edges_w[sorted_targets[i]])+"\n")
        file.write(source+"\t"+edges_t[sorted_targets[i]]+"\t"+str(edges_w[sorted_targets[i]])+"\n")
    #break
    #file.write(source+","+target+","+str(weight)+"\n")
        #series=pd.Series({'Source':source, 'Target':target, 'Weight':weight})
        #game_df = pd.concat([game_df,series])
        #game_df = game_df.append(series, ignore_index=True)
    #output_df = pd.concat([output_df, game_df])
    game_number+=1
file.close()
#output_df.head()
# Out:
# 0
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# 11000
# 12000

# %%
file.close()
